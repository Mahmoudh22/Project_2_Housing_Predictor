# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  675000.0         4        1.0         1180      7140     1.0         NO
# 1  920000.0         5        2.5         2770      6703     1.0         NO
# 2  775000.0         3        3.0         2160      1400     2.0         NO
# 3  592500.0         2        2.0         1120       758     2.0         NO
# 4  625000.0         2        1.0         1190      5688     1.0         NO
#
#   greenbelt nuisance     view  ...  heat_source sewer_system sqft_above  \
# 0        NO       NO     NONE  ...          Gas       PUBLIC       1180
# 1        NO      YES  AVERAGE  ...          Oil       PUBLIC       1570
# 2        NO       NO  AVERAGE  ...          Gas       PUBLIC       1090
# 3        NO      YES     NONE  ...  Electricity       PUBLIC       1120
# 4        NO      YES     NONE  ...  Electricity       PUBLIC       1190
#
#   sqft_basement  sqft_garage  sqft_patio  yr_built  \
# 0             0            0          40      1969
# 1          1570            0         240      1950
# 2          1070          200         270      2010
# 3           550          550          30      2012
# 4             0          300           0      1948
#
#                                              address       state zip_code
# 0  2102 Southeast 21st Court, Renton, Washington ...  Washington     2102
# 1  11231 Greenwood Avenue North, Seattle, Washing...  Washington    11231
# 2  4079 Letitia Avenue South, Seattle, Washington...  Washington     4079
# 3  2193 Northwest Talus Drive, Issaquah, Washingt...  Washington     2193
# 4  1602 North 185th Street, Shoreline, Washington...  Washington     1602
#
# [5 rows x 22 columns]

# %%
df.select_dtypes(exclude=['object']).head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0  675000.0         4        1.0         1180      7140     1.0        1180
# 1  920000.0         5        2.5         2770      6703     1.0        1570
# 2  775000.0         3        3.0         2160      1400     2.0        1090
# 3  592500.0         2        2.0         1120       758     2.0        1120
# 4  625000.0         2        1.0         1190      5688     1.0        1190
#
#    sqft_basement  sqft_garage  sqft_patio  yr_built
# 0              0            0          40      1969
# 1           1570            0         240      1950
# 2           1070          200         270      2010
# 3            550          550          30      2012
# 4              0          300           0      1948

# %% [markdown]
# # what we need to predict price:
# 1. Bedrooms
# 2. Bathrooms
# 3. sqft lot

# %%
df.select_dtypes(include=['object']).head()
# Out:
#   waterfront greenbelt nuisance     view condition      grade  heat_source  \
# 0         NO        NO       NO     NONE      Good  7 Average          Gas
# 1         NO        NO      YES  AVERAGE   Average  7 Average          Oil
# 2         NO        NO       NO  AVERAGE   Average   9 Better          Gas
# 3         NO        NO      YES     NONE   Average  7 Average  Electricity
# 4         NO        NO      YES     NONE   Average  7 Average  Electricity
#
#   sewer_system                                            address       state  \
# 0       PUBLIC  2102 Southeast 21st Court, Renton, Washington ...  Washington
# 1       PUBLIC  11231 Greenwood Avenue North, Seattle, Washing...  Washington
# 2       PUBLIC  4079 Letitia Avenue South, Seattle, Washington...  Washington
# 3       PUBLIC  2193 Northwest Talus Drive, Issaquah, Washingt...  Washington
# 4       PUBLIC  1602 North 185th Street, Shoreline, Washington...  Washington
#
#   zip_code
# 0     2102
# 1    11231
# 2     4079
# 3     2193
# 4     1602

# %% [markdown]
# # What we need to predict price:
# 1. Grade
# 2. heat source
# 3. sewer_system
# 4. state

# %% [markdown]
# # Ordinal Data

# %%
df['grade'].unique()
# Out:
# array(['7 Average', '9 Better', '8 Good', '6 Low Average', '5 Fair',
#        '4 Low', '10 Very Good', '11 Excellent', '3 Poor', '12 Luxury'],
#       dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# ordering the grade column
grade_order = ['3 Poor', '4 Low', '5 Fair', '6 Low Average', '7 Average', '8 Good', '9 Better', 
               '10 Very Good', '11 Excellent', '12 Luxury']

reg_grade_order = ['7 Average', '9 Better', '8 Good', '6 Low Average', '5 Fair',
       '4 Low', '10 Very Good', '11 Excellent', '3 Poor', '12 Luxury']

# %% [markdown]
# # Nomial Data

# %%
df['heat_source'].unique()
# Out:
# array(['Gas', 'Oil', 'Electricity', 'Gas/Solar', 'Other',
#        'Electricity/Solar', 'Oil/Solar'], dtype=object)

# %%
df['heat_source'].value_counts()
# Out:
# Gas                  10136
# Electricity           4403
# Oil                   1802
# Electricity/Solar       24
# Gas/Solar               20
# Other                    9
# Oil/Solar                3
# Name: heat_source, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_enc = OneHotEncoder()
# heat source
nominal_data = ['heat_source','sewer_system','state','waterfront','greenbelt']
X_nom_trans = onehot_enc.fit_transform(df[nominal_data])
