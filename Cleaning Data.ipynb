# %%
import pandas as pd

# %%
# importing data
df = pd.read_csv('data/kc_house_data.csv')

# %%
# viewing data
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7399300360   5/24/2022  675000.0         4        1.0         1180
# 1  8910500230  12/13/2021  920000.0         5        2.5         2770
# 2  1180000275   9/29/2021  311000.0         6        2.0         2880
# 3  1604601802  12/14/2021  775000.0         3        3.0         2160
# 4  8562780790   8/24/2021  592500.0         2        2.0         1120
#
#    sqft_lot  floors waterfront greenbelt  ... sewer_system sqft_above  \
# 0      7140     1.0         NO        NO  ...       PUBLIC       1180
# 1      6703     1.0         NO        NO  ...       PUBLIC       1570
# 2      6156     1.0         NO        NO  ...       PUBLIC       1580
# 3      1400     2.0         NO        NO  ...       PUBLIC       1090
# 4       758     2.0         NO        NO  ...       PUBLIC       1120
#
#   sqft_basement sqft_garage sqft_patio yr_built  yr_renovated  \
# ...

# %%
# viewing the '...' data we could not see above
df.loc[:,'greenbelt':]
# Out:
#       greenbelt nuisance     view condition      grade  heat_source  \
# 0            NO       NO     NONE      Good  7 Average          Gas
# 1            NO      YES  AVERAGE   Average  7 Average          Oil
# 2            NO       NO  AVERAGE   Average  7 Average          Gas
# 3            NO       NO  AVERAGE   Average   9 Better          Gas
# 4            NO      YES     NONE   Average  7 Average  Electricity
# ...         ...      ...      ...       ...        ...          ...
# 30150        NO       NO     NONE      Good     8 Good          Oil
# 30151        NO       NO     FAIR   Average  7 Average          Gas
# 30152        NO      YES     NONE   Average  7 Average          Gas
# 30153        NO       NO     NONE   Average     8 Good          Gas
# 30154        NO       NO     NONE   Average  7 Average          Oil
#
#       sewer_system  sqft_above  sqft_basement  sqft_garage  sqft_patio  \
# 0           PUBLIC        1180              0            0          40
# ...

# %%
df['sewer_system'].unique()
# Out:
# array(['PUBLIC', 'PRIVATE', 'PRIVATE RESTRICTED', nan,
#        'PUBLIC RESTRICTED'], dtype=object)

# %%
# this row is a duplicate of another row
duplicates = df[df.duplicated()]
duplicates
# Out:
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 4846  1233100736  9/28/2021  2600000.0         3        4.0         3500
#
#       sqft_lot  floors waterfront greenbelt  ... sewer_system sqft_above  \
# 4846      8455     2.0         NO        NO  ...       PUBLIC       2590
#
#      sqft_basement sqft_garage sqft_patio yr_built  yr_renovated  \
# 4846          1410         500        290     2019             0
#
#                                                 address       lat        long
# 4846  12611 Northeast 87th Place, Kirkland, Washingt...  47.68069 -122.172135
#
# [1 rows x 25 columns]

# %%
# dropping the duplicated row
df.drop_duplicates()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7399300360   5/24/2022   675000.0         4        1.0         1180
# 1      8910500230  12/13/2021   920000.0         5        2.5         2770
# 2      1180000275   9/29/2021   311000.0         6        2.0         2880
# 3      1604601802  12/14/2021   775000.0         3        3.0         2160
# 4      8562780790   8/24/2021   592500.0         2        2.0         1120
# ...           ...         ...        ...       ...        ...          ...
# 30150  7834800180  11/30/2021  1555000.0         5        2.0         1910
# 30151   194000695   6/16/2021  1313000.0         3        2.0         2020
# 30152  7960100080   5/27/2022   800000.0         3        2.0         1620
# 30153  2781280080   2/24/2022   775000.0         3        2.5         2570
# 30154  9557800100   4/29/2022   500000.0         3        1.5         1200
#
# ...

# %%
# checking for NaN
df.isnull().sum()
# Out:
# id                0
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# greenbelt         0
# nuisance          0
# view              0
# condition         0
# grade             0
# heat_source      32
# sewer_system     14
# sqft_above        0
# sqft_basement     0
# sqft_garage       0
# sqft_patio        0
# yr_built          0
# yr_renovated      0
# address           0
# lat               0
# long              0
# dtype: int64

# %%
# dropping the Nulls
df = df.dropna()
df.shape
# Out:
# (30111, 25)

# %%
# dropping the unnescary columns: id, 
df_h = df.drop(['id', 'date', 'lat', 'long'], axis = 1)
df_h.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  675000.0         4        1.0         1180      7140     1.0         NO
# 1  920000.0         5        2.5         2770      6703     1.0         NO
# 2  311000.0         6        2.0         2880      6156     1.0         NO
# 3  775000.0         3        3.0         2160      1400     2.0         NO
# 4  592500.0         2        2.0         1120       758     2.0         NO
#
#   greenbelt nuisance     view  ...      grade  heat_source sewer_system  \
# 0        NO       NO     NONE  ...  7 Average          Gas       PUBLIC
# 1        NO      YES  AVERAGE  ...  7 Average          Oil       PUBLIC
# 2        NO       NO  AVERAGE  ...  7 Average          Gas       PUBLIC
# 3        NO       NO  AVERAGE  ...   9 Better          Gas       PUBLIC
# 4        NO      YES     NONE  ...  7 Average  Electricity       PUBLIC
#
#   sqft_above  sqft_basement  sqft_garage  sqft_patio  yr_built  yr_renovated  \
# ...

# %%
# we want zip code only rather than address. 
zip_code = [x.split()[0] for x in df['address']]
len(zip_code)
# Out:
# 30111

# %%
# creating a column for zip code
df_h['zip_code'] = zip_code
df_h
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       675000.0         4        1.0         1180      7140     1.0
# 1       920000.0         5        2.5         2770      6703     1.0
# 2       311000.0         6        2.0         2880      6156     1.0
# 3       775000.0         3        3.0         2160      1400     2.0
# 4       592500.0         2        2.0         1120       758     2.0
# ...          ...       ...        ...          ...       ...     ...
# 30150  1555000.0         5        2.0         1910      4000     1.5
# 30151  1313000.0         3        2.0         2020      5800     2.0
# 30152   800000.0         3        2.0         1620      3600     1.0
# 30153   775000.0         3        2.5         2570      2889     2.0
# 30154   500000.0         3        1.5         1200     11058     1.0
#
#       waterfront greenbelt nuisance     view  ...  heat_source sewer_system  \
# ...

# %%
# delete the address column

# %% [markdown]
# # Flippers looking to flip houses, what can they do to increase the house price when flipping?

# %% [markdown]
# #
