# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing data
df = pd.read_csv('data/kc_house_data.csv')

# %%
# trying to create state column

state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", 
               "Colorado", "Connecticut", "District ", "of Columbia", "Delaware", "Florida", 
               "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", 
               "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", 
               "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", 
               "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", 
               "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", 
               "West Virginia", "Wyoming"]





# this goes thourgh each row in the df of address and check to see if 1 of the state appears in the row,
# then appends the state name to the row
state = pd.Series([st_name for row in df['address'] for st_name in state_names if st_name in row.split()])

df['state'] = state

# %%
# creating a column for zip code
zip_code = [x.split()[0] for x in df['address']]
df['zip_code'] = zip_code
# dropping the unneed colmns 
df = df.drop(['id', 'date', 'lat', 'long','yr_renovated'], axis = 1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  675000.0         4        1.0         1180      7140     1.0         NO
# 1  920000.0         5        2.5         2770      6703     1.0         NO
# 2  311000.0         6        2.0         2880      6156     1.0         NO
# 3  775000.0         3        3.0         2160      1400     2.0         NO
# 4  592500.0         2        2.0         1120       758     2.0         NO
#
#   greenbelt nuisance     view  ...  heat_source sewer_system sqft_above  \
# 0        NO       NO     NONE  ...          Gas       PUBLIC       1180
# 1        NO      YES  AVERAGE  ...          Oil       PUBLIC       1570
# 2        NO       NO  AVERAGE  ...          Gas       PUBLIC       1580
# 3        NO       NO  AVERAGE  ...          Gas       PUBLIC       1090
# 4        NO      YES     NONE  ...  Electricity       PUBLIC       1120
#
#   sqft_basement  sqft_garage  sqft_patio  yr_built  \
# 0             0            0          40      1969
# 1          1570            0         240      1950
# 2          1580            0           0      1956
# 3          1070          200         270      2010
# 4           550          550          30      2012
#
#                                              address       state zip_code
# 0  2102 Southeast 21st Court, Renton, Washington ...  Washington     2102
# 1  11231 Greenwood Avenue North, Seattle, Washing...  Washington    11231
# 2  8504 South 113th Street, Seattle, Washington 9...  Washington     8504
# 3  4079 Letitia Avenue South, Seattle, Washington...  Washington     4079
# 4  2193 Northwest Talus Drive, Issaquah, Washingt...  Washington     2193
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (30155, 22)

# %%
df.isna().sum()
# Out:
# price              0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         0
# greenbelt          0
# nuisance           0
# view               0
# condition          0
# grade              0
# heat_source       32
# sewer_system      14
# sqft_above         0
# sqft_basement      0
# sqft_garage        0
# sqft_patio         0
# yr_built           0
# address            0
# state            109
# zip_code           0
# dtype: int64

# %%
# dropping the duplicated row
df.drop_duplicates()
# dropping the Nulls
df = df.dropna()

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  675000.0         4        1.0         1180      7140     1.0         NO
# 1  920000.0         5        2.5         2770      6703     1.0         NO
# 2  311000.0         6        2.0         2880      6156     1.0         NO
# 3  775000.0         3        3.0         2160      1400     2.0         NO
# 4  592500.0         2        2.0         1120       758     2.0         NO
#
#   greenbelt nuisance     view  ...  heat_source sewer_system sqft_above  \
# 0        NO       NO     NONE  ...          Gas       PUBLIC       1180
# 1        NO      YES  AVERAGE  ...          Oil       PUBLIC       1570
# 2        NO       NO  AVERAGE  ...          Gas       PUBLIC       1580
# 3        NO       NO  AVERAGE  ...          Gas       PUBLIC       1090
# 4        NO      YES     NONE  ...  Electricity       PUBLIC       1120
#
#   sqft_basement  sqft_garage  sqft_patio  yr_built  \
# 0             0            0          40      1969
# 1          1570            0         240      1950
# 2          1580            0           0      1956
# 3          1070          200         270      2010
# 4           550          550          30      2012
#
#                                              address       state zip_code
# 0  2102 Southeast 21st Court, Renton, Washington ...  Washington     2102
# 1  11231 Greenwood Avenue North, Seattle, Washing...  Washington    11231
# 2  8504 South 113th Street, Seattle, Washington 9...  Washington     8504
# 3  4079 Letitia Avenue South, Seattle, Washington...  Washington     4079
# 4  2193 Northwest Talus Drive, Issaquah, Washingt...  Washington     2193
#
# [5 rows x 22 columns]

# %%
# plotting the see the data, and to see the outliers 
import plotly.express as px
fig = px.box(df, y="price")
fig.show()
# Out:
# <div>                            <div id="328f118f-1769-4c9a-bbaa-5d076deb6885" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("328f118f-1769-4c9a-bbaa-5d076deb6885")) {                    Plotly.newPlot(                        "328f118f-1769-4c9a-bbaa-5d076deb6885",                        [{"alignmentgroup":"True","hovertemplate":"price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[675000.0,920000.0,311000.0,775000.0,592500.0,625000.0,1317227.0,820000.0,780000.0,975000.0,1025000.0,680000.0,750000.0,828000.0,661000.0,1500000.0,1318000.0,735000.0,739950.0,702000.0,1320000.0,750000.0,450000.0,1650000.0,785000.0,580000.0,2000000.0,4500000.0,1625000.0,880000.0,500000.0,730000.0,670000.0,625000.0,785000.0,2065000.0,2450000.0,1379400.0,785000.0,1680000.0,750000.0,1600000.0,1709500.0,3850000.0,1800000.0,315000.0,995930.0,706000.0,810000.0,1220000.0,1000000.0,1090000.0,235000.0,960000.0,835000.0,656000.0,37440.0,765000.0,770000.0,645000.0,1500000.0,740000.0,740000.0,1500000.0,1835000.0,905000.0,1007500.0,275000.0,590000.0,871000.0,1375000.0,770000.0,1600000.0,609000.0,1825000.0,1119725.0,1516000.0,1560000.0,687388.0,1575000.0,694000.0,370000.0,1200000.0,825000.0,2500000.0,900000.0,1225000.0,950000.0,1061000.0,426000.0,279370.0,810000.0,708888.0,742000.0,800000.0,825000.0,850000.0,725000.0,825000.0,700000.0,440000.0,1300000.0,1350000.0,1500000.0,830000.0,620000.0,599000.0,575000.0,800000.0,800000.0,1265000.0,728000.0,725000.0,935000.0,410000.0,750000.0,482000.0,900000.0,3000000.0,610000.0,665250.0,765000.0,665000.0,855000.0,725000.0,845000.0,505000.0,426000.
#  The 25th percentile: 649000.0
#  The lower Fence 327500.0
#  The InterQuartile Range: 651000.0
#  The minimum: 27360.0
#  The mean: 1108950.3923738417

# %%
# reducing the dataset to only  to from lower fence (326,900) to the q3 (1.3M) 
# making it that we have no outliers in the data, 
# it will be eariser for us to look at homes for lower income family, and middle class families
new_df = df[(df['price'] <= q3) & (df['price'] >= low_fence)]
new_df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      675000.0         4        1.0         1180      7140     1.0
# 1      920000.0         5        2.5         2770      6703     1.0
# 3      775000.0         3        3.0         2160      1400     2.0
# 4      592500.0         2        2.0         1120       758     2.0
# 5      625000.0         2        1.0         1190      5688     1.0
# ...         ...       ...        ...          ...       ...     ...
# 30041  900000.0         5        4.5         2950      4804     2.0
# 30042  600000.0         3        1.5         1330      6650     1.0
# 30043  700000.0         4        3.0         2320      9419     1.0
# 30044  520000.0         2        2.0          790       597     2.0
# 30045  603055.0         3        2.5         2120      4500     2.0
#
#       waterfront greenbelt nuisance     view  ...  heat_source sewer_system  \
# 0             NO        NO       NO     NONE  ...          Gas       PUBLIC
# 1             NO        NO      YES  AVERAGE  ...          Oil       PUBLIC
# 3             NO        NO       NO  AVERAGE  ...          Gas       PUBLIC
# 4             NO        NO      YES     NONE  ...  Electricity       PUBLIC
# 5             NO        NO      YES     NONE  ...  Electricity       PUBLIC
# ...          ...       ...      ...      ...  ...          ...          ...
# 30041         NO        NO      YES     NONE  ...          Gas       PUBLIC
# 30042         NO        NO       NO     NONE  ...          Gas       PUBLIC
# 30043         NO        NO       NO     NONE  ...          Oil       PUBLIC
# 30044         NO        NO       NO     NONE  ...  Electricity       PUBLIC
# 30045         NO        NO       NO     NONE  ...          Gas       PUBLIC
#
#       sqft_above sqft_basement  sqft_garage  sqft_patio  yr_built  \
# 0           1180             0            0          40      1969
# 1           1570          1570            0         240      1950
# 3           1090          1070          200         270      2010
# 4           1120           550          550          30      2012
# 5           1190             0          300           0      1948
# ...          ...           ...          ...         ...       ...
# 30041       2120          1230          400         110      1987
# 30042        900           430          440         290      1973
# 30043       1160          1160            0           0      1953
# 30044        520           270            0         210      2021
# 30045       2120             0          430          60      2022
#
#                                                  address       state zip_code
# 0      2102 Southeast 21st Court, Renton, Washington ...  Washington     2102
# 1      11231 Greenwood Avenue North, Seattle, Washing...  Washington    11231
# 3      4079 Letitia Avenue South, Seattle, Washington...  Washington     4079
# 4      2193 Northwest Talus Drive, Issaquah, Washingt...  Washington     2193
# 5      1602 North 185th Street, Shoreline, Washington...  Washington     1602
# ...                                                  ...         ...      ...
# 30041  12005 Sand Point Way Northeast, Seattle, Washi...  Washington    12005
# 30042  10236 41st Avenue Southwest, Seattle, Washingt...  Washington    10236
# 30043  8904 South 121st Street, Seattle, Washington 9...  Washington     8904
# 30044  36th Avenue, Kenosha, Wisconsin 53142, United ...  Washington     36th
# 30045  25313 174th Place Southeast, Covington, Washin...  Washington    25313
#
# [21857 rows x 22 columns]

# %%
# NO outliers 
fig = px.box(new_df, y="price")
fig.show()
# Out:
# <div>                            <div id="797a49e6-156d-4622-b715-4c11d5772aca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
300000.0,517000.0,1100000.0,599900.0,1200000.0,724950.0,750000.0,680000.0,789950.0,687500.0,760000.0,925000.0,1125000.0,475000.0,725000.0,1050000.0,775000.0,809500.0,515000.0,950000.0,1191074.0,405000.0,775000.0,1050000.0,440000.0,460000.0,760600.0,799000.0,625000.0,648000.0,789000.0,920000.0,820000.0,950000.0,756000.0,575000.0,798860.0,420000.0,1119000.0,750000.0,800000.0,815000.0,633000.0,390000.0,699900.0,1000000.0,819000.0,550000.0,802000.0,410000.0,1038000.0,850000.0,455000.0,1025642.0,1131000.0,700000.0,1210000.0,685000.0,535000.0,835000.0,699000.0,415000.0,687500.0,820000.0,902500.0,445000.0,769999.0,405000.0,1195000.0,1010000.0,805000.0,980000.0,850000.0,810000.0,479950.0,480000.0,595000.0,431000.0,650000.0,605000.0,1190000.0,675000.0,775000.0,602000.0 ...

# %% [markdown]
# # we can even go and get rid of max beign 1.3M because no middle class or low class can afford that.
# https://www.fool.com/the-ascent/research/average-house-price-state/
#
# https://www.businessinsider.com/how-expensive-houses-us-median-home-price-mortgage-interest-2022-2

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21857 entries, 0 to 30045
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21857 non-null  float64
#  1   bedrooms       21857 non-null  int64
#  2   bathrooms      21857 non-null  float64
#  3   sqft_living    21857 non-null  int64
#  4   sqft_lot       21857 non-null  int64
#  5   floors         21857 non-null  float64
#  6   waterfront     21857 non-null  object
#  7   greenbelt      21857 non-null  object
#  8   nuisance       21857 non-null  object
#  9   view           21857 non-null  object
#  10  condition      21857 non-null  object
#  11  grade          21857 non-null  object
#  12  heat_source    21857 non-null  object
#  13  sewer_system   21857 non-null  object
#  14  sqft_above     21857 non-null  int64
#  15  sqft_basement  21857 non-null  int64
#  16  sqft_garage    21857 non-null  int64
#  17  sqft_patio     21857 non-null  int64
#  18  yr_built       21857 non-null  int64
#  19  address        21857 non-null  object
#  20  state          21857 non-null  object
#  21  zip_code       21857 non-null  object
# dtypes: float64(3), int64(8), object(11)
# memory usage: 3.8+ MB

# %%
# checking out the non numberical columns
obj = new_df.select_dtypes(include= ['object'])
obj = obj.drop('zip_code', axis = 1)
obj.head()
# Out:
#   waterfront greenbelt nuisance     view condition      grade  heat_source  \
# 0         NO        NO       NO     NONE      Good  7 Average          Gas
# 1         NO        NO      YES  AVERAGE   Average  7 Average          Oil
# 3         NO        NO       NO  AVERAGE   Average   9 Better          Gas
# 4         NO        NO      YES     NONE   Average  7 Average  Electricity
# 5         NO        NO      YES     NONE   Average  7 Average  Electricity
#
#   sewer_system                                            address       state
# 0       PUBLIC  2102 Southeast 21st Court, Renton, Washington ...  Washington
# 1       PUBLIC  11231 Greenwood Avenue North, Seattle, Washing...  Washington
# 3       PUBLIC  4079 Letitia Avenue South, Seattle, Washington...  Washington
# 4       PUBLIC  2193 Northwest Talus Drive, Issaquah, Washingt...  Washington
# 5       PUBLIC  1602 North 185th Street, Shoreline, Washington...  Washington

# %%
# checking the non numberical columns for any with low values, so we can get rid of them
# dont worry about this, i was just curious 
name = list(obj.columns)
col_val_count = {}
for x in range(len(name)):
    col_val_count[name[x]] = obj[name[x]].value_counts()
col_val_count
# Out:
# {'waterfront': NO     21646
#  YES      211
#  Name: waterfront, dtype: int64,
#  'greenbelt': NO     21486
#  YES      371
#  Name: greenbelt, dtype: int64,
#  'nuisance': NO     18020
#  YES     3837
#  Name: nuisance, dtype: int64,
#  'view': NONE         20210
#  AVERAGE       1050
#  GOOD           361
#  EXCELLENT      135
#  FAIR           101
#  Name: view, dtype: int64,
#  'condition': Average      13441
#  Good          5926
#  Very Good     2271
#  Fair           172
#  Poor            47
#  Name: condition, dtype: int64,
#  'grade': 7 Average        10345
#  8 Good            6851
#  6 Low Average     2567
#  9 Better          1569
#  5 Fair             311
#  10 Very Good       165
#  4 Low               30
#  11 Excellent        12
#  3 Poor               6
#  12 Luxury            1
#  Name: grade, dtype: int64,
#  'heat_source': Gas                  13972
#  Electricity           5405
#  Oil                   2391
#  Gas/Solar               37
#  Electricity/Solar       35
#  Other                   14
#  Oil/Solar                3
#  Name: heat_source, dtype: int64,
#  'sewer_system': PUBLIC                18740
#  PRIVATE                3113
#  PRIVATE RESTRICTED        2
#  PUBLIC RESTRICTED         2
#  Name: sewer_system, dtype: int64,
#  'address': Avenue, 108 Foothill Blvd, Rancho Cucamonga, California 91730, United States    38
#  Delridge Way Southwest, Seattle, Washington 98106, United States                24
#  9th Ave, Nebraska City, Nebraska 68410, United States                           21
#  A, Leadwood, Missouri 63653, United States                                      17
#  15th Avenue, Plattsmouth, Nebraska 68048, United States                         17
#                                                                                  ..
#  26827 194th Avenue Southeast, Covington, Washington 98042, United States         1
#  814 North 128th Street, Seattle, Washington 98133, United States                 1
#  1944 Olympia Court Southeast, Renton, Washington 98058, United States            1
#  10736 28th Avenue Southwest, Seattle, Washington 98146, United States            1
#  40527 264th Avenue Southeast, Enumclaw, Washington 98022, United States          1
#  Name: address, Length: 21309, dtype: int64,
#  'state': Washington       21268
#  Nebraska           122
#  California          71
#  Minnesota           43
#  Wisconsin           41
#  Missouri            40
#  Oregon              28
#  Illinois            27
#  Colorado            25
#  Pennsylvania        25
#  Massachusetts       24
#  Indiana             21
#  Kansas              17
#  Ohio                17
#  Florida             14
#  Iowa                11
#  Nevada              11
#  Alaska              10
#  Texas                8
#  Virginia             7
#  Arizona              7
#  Michigan             5
#  Montana              4
#  Utah                 4
#  Oklahoma             2
#  Hawaii               2
#  Arkansas             1
#  Idaho                1
#  Louisiana            1
#  Name: state, dtype: int64}

# %%
# making a new dataset with q3 in the new_df (940k) as the max

new_q3= np.percentile(new_df['price'],75)
new_min = new_df['price'].min()
df_h = new_df[(new_df['price'] <= new_q3) & (new_df['price'] >= new_min)]
df_h
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      675000.0         4        1.0         1180      7140     1.0
# 1      920000.0         5        2.5         2770      6703     1.0
# 3      775000.0         3        3.0         2160      1400     2.0
# 4      592500.0         2        2.0         1120       758     2.0
# 5      625000.0         2        1.0         1190      5688     1.0
# ...         ...       ...        ...          ...       ...     ...
# 30041  900000.0         5        4.5         2950      4804     2.0
# 30042  600000.0         3        1.5         1330      6650     1.0
# 30043  700000.0         4        3.0         2320      9419     1.0
# 30044  520000.0         2        2.0          790       597     2.0
# 30045  603055.0         3        2.5         2120      4500     2.0
#
#       waterfront greenbelt nuisance     view  ...  heat_source sewer_system  \
# 0             NO        NO       NO     NONE  ...          Gas       PUBLIC
# 1             NO        NO      YES  AVERAGE  ...          Oil       PUBLIC
# 3             NO        NO       NO  AVERAGE  ...          Gas       PUBLIC
# 4             NO        NO      YES     NONE  ...  Electricity       PUBLIC
# 5             NO        NO      YES     NONE  ...  Electricity       PUBLIC
# ...          ...       ...      ...      ...  ...          ...          ...
# 30041         NO        NO      YES     NONE  ...          Gas       PUBLIC
# 30042         NO        NO       NO     NONE  ...          Gas       PUBLIC
# 30043         NO        NO       NO     NONE  ...          Oil       PUBLIC
# 30044         NO        NO       NO     NONE  ...  Electricity       PUBLIC
# 30045         NO        NO       NO     NONE  ...          Gas       PUBLIC
#
#       sqft_above sqft_basement  sqft_garage  sqft_patio  yr_built  \
# 0           1180             0            0          40      1969
# 1           1570          1570            0         240      1950
# 3           1090          1070          200         270      2010
# 4           1120           550          550          30      2012
# 5           1190             0          300           0      1948
# ...          ...           ...          ...         ...       ...
# 30041       2120          1230          400         110      1987
# 30042        900           430          440         290      1973
# 30043       1160          1160            0           0      1953
# 30044        520           270            0         210      2021
# 30045       2120             0          430          60      2022
#
#                                                  address       state zip_code
# 0      2102 Southeast 21st Court, Renton, Washington ...  Washington     2102
# 1      11231 Greenwood Avenue North, Seattle, Washing...  Washington    11231
# 3      4079 Letitia Avenue South, Seattle, Washington...  Washington     4079
# 4      2193 Northwest Talus Drive, Issaquah, Washingt...  Washington     2193
# 5      1602 North 185th Street, Shoreline, Washington...  Washington     1602
# ...                                                  ...         ...      ...
# 30041  12005 Sand Point Way Northeast, Seattle, Washi...  Washington    12005
# 30042  10236 41st Avenue Southwest, Seattle, Washingt...  Washington    10236
# 30043  8904 South 121st Street, Seattle, Washington 9...  Washington     8904
# 30044  36th Avenue, Kenosha, Wisconsin 53142, United ...  Washington     36th
# 30045  25313 174th Place Southeast, Covington, Washin...  Washington    25313
#
# [16397 rows x 22 columns]

# %%
fig = px.box(df_h, y="price")
fig.show()
# Out:
# <div>                            <div id="6b76e58f-a124-4547-b659-8cdac4b80276" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b76e58f-a124-4547-b659-8cdac4b80276")) {                    Plotly.newPlot(                        "6b76e58f-a124-4547-b659-8cdac4b80276",                        [{"alignmentgroup":"True","hovertemplate":"price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[675000.0,920000.0,775000.0,592500.0,625000.0,820000.0,780000.0,680000.0,750000.0,828000.0,661000.0,735000.0,739950.0,702000.0,750000.0,450000.0,785000.0,580000.0,880000.0,500000.0,730000.0,670000.0,625000.0,785000.0,785000.0,750000.0,706000.0,810000.0,835000.0,656000.0,765000.0,770000.0,645000.0,740000.0,740000.0,905000.0,590000.0,871000.0,770000.0,609000.0,687388.0,694000.0,370000.0,825000.0,900000.0,426000.0,810000.0,708888.0,
# %% [markdown]
# # Thought
# ## Business Idea:
# ### A real estate company came to us and asked us to find and predit values for homes for low and middle class families, because it is hard to find homes for the average american after the covid crisis

# %%
# tyring to get the average house price per state

state_list = df_h['state'].value_counts().index

state_avg = {}
for name in state_list:
    state_avg[name] = round(df_h[(df_h['state'] == name)]['price'].mean(),3)

# %%
state_avg_price = pd.DataFrame.from_dict(state_avg, orient='index',
                       columns=['avg_price'])

# %%
state_avg_price.reset_index(inplace=True)

# %%
state_avg_price.rename(columns={"index":'state'}, inplace=True)

# %%
state_avg_price
# Out:
#             state   avg_price
# 0      Washington  677450.622
# 1        Nebraska  691323.437
# 2      California  648249.980
# 3       Minnesota  681753.000
# 4        Missouri  699053.097
# 5       Wisconsin  676018.704
# 6    Pennsylvania  703430.952
# 7          Oregon  688497.619
# 8        Illinois  659092.857
# 9        Colorado  744234.950
# 10  Massachusetts  695503.211
# 11        Indiana  663443.750
# 12         Kansas  657535.714
# 13           Ohio  673615.385
# 14        Florida  755815.000
# 15         Alaska  710000.000
# 16           Iowa  687875.000
# 17       Virginia  779428.571
# 18         Nevada  713571.429
# 19          Texas  631283.833
# 20        Arizona  571895.667
# 21           Utah  620750.000
# 22        Montana  573000.000
# 23       Michigan  631666.667
# 24       Oklahoma  600500.000
# 25         Hawaii  667500.000
# 26       Arkansas  505000.000

# %%
code = {'Alabama': 'AL',
        'Alaska': 'AK',
        'Arizona': 'AZ',
        'Arkansas': 'AR',
        'California': 'CA',
        'Colorado': 'CO',
        'Connecticut': 'CT',
        'Delaware': 'DE',
        'District of Columbia': 'DC',
        'Florida': 'FL',
        'Georgia': 'GA',
        'Hawaii': 'HI',
        'Idaho': 'ID',
        'Illinois': 'IL',
        'Indiana': 'IN',
        'Iowa': 'IA',
        'Kansas': 'KS',
        'Kentucky': 'KY',
        'Louisiana': 'LA',
        'Maine': 'ME',
        'Maryland': 'MD',
        'Massachusetts': 'MA',
        'Michigan': 'MI',
        'Minnesota': 'MN',
        'Mississippi': 'MS',
        'Missouri': 'MO',
        'Montana': 'MT',
        'Nebraska': 'NE',
        'Nevada': 'NV',
        'New Hampshire': 'NH',
        'New Jersey': 'NJ',
        'New Mexico': 'NM',
        'New York': 'NY',
        'North Carolina': 'NC',
        'North Dakota': 'ND',
        'Ohio': 'OH',
        'Oklahoma': 'OK',
        'Oregon': 'OR',
        'Pennsylvania': 'PA',
        'Rhode Island': 'RI',
        'South Carolina': 'SC',
        'South Dakota': 'SD',
        'Tennessee': 'TN',
        'Texas': 'TX',
        'Utah': 'UT',
        'Vermont': 'VT',
        'Virginia': 'VA',
        'Washington': 'WA',
        'West Virginia': 'WV',
        'Wisconsin': 'WI',
        'Wyoming': 'WY'}

# %%
state_avg_price['code'] = state_avg_price['state'].map(code)

# %%
state_avg_price
# Out:
#             state   avg_price code
# 0      Washington  677450.622   WA
# 1        Nebraska  691323.437   NE
# 2      California  648249.980   CA
# 3       Minnesota  681753.000   MN
# 4        Missouri  699053.097   MO
# 5       Wisconsin  676018.704   WI
# 6    Pennsylvania  703430.952   PA
# 7          Oregon  688497.619   OR
# 8        Illinois  659092.857   IL
# 9        Colorado  744234.950   CO
# 10  Massachusetts  695503.211   MA
# 11        Indiana  663443.750   IN
# 12         Kansas  657535.714   KS
# 13           Ohio  673615.385   OH
# 14        Florida  755815.000   FL
# 15         Alaska  710000.000   AK
# 16           Iowa  687875.000   IA
# 17       Virginia  779428.571   VA
# 18         Nevada  713571.429   NV
# 19          Texas  631283.833   TX
# 20        Arizona  571895.667   AZ
# 21           Utah  620750.000   UT
# 22        Montana  573000.000   MT
# 23       Michigan  631666.667   MI
# 24       Oklahoma  600500.000   OK
# 25         Hawaii  667500.000   HI
# 26       Arkansas  505000.000   AR

# %%
fig = px.choropleth(state_avg_price,
                    locations='code',
                    color='avg_price',
                    color_continuous_scale='spectral_r',
                    hover_name='state',
                    locationmode='USA-states',
                    labels={'avg_price':'Price'},
                    scope='usa')

fig.add_scattergeo(locations=state_avg_price['code'],
                   locationmode='USA-states',
                  text=state_avg_price['code'],
                  mode='text')

fig.update_layout(
    title={'text':'Average Price of House per State',
           'xanchor':'center',
           'yanchor':'top',
           'x':0.5,})
# Out:
# <div>                            <div id="c614d51d-6f9b-4253-a495-c62036e9d3bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c614d51d-6f9b-4253-a495-c62036e9d3bd")) {                    Plotly.newPlot(                        "c614d51d-6f9b-4253-a495-c62036e9d3bd",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>code=%{location}<br>Price=%{z}<extra></extra>","hovertext":["Washington","Nebraska","California","Minnesota","Missouri","Wisconsin","Pennsylvania","Oregon","Illinois","Colorado","Massachusetts","Indiana","Kansas","Ohio","Florida","Alaska","Iowa","Virginia","Nevada","Texas","Arizona","Utah","Montana","Michigan","Oklahoma","Hawaii","Arkansas"],"locationmode":"USA-states","locations":["WA","NE","CA","MN","MO","WI","PA","OR","IL","CO","MA","IN","KS","OH","FL","AK","IA","VA","NV","TX","AZ","UT","MT","MI","OK","HI","AR"],"name":"","z":[677450.622,691323.437,648249.98,681753.0,699053.097,676018.704,703430.952,688497.619,659092.857,744234.95,695503.211,663443.75,657535.714,673615.385,755815.0,710000.0,687875.0,779428.571,713571.429,631283.833,571895.667,620750.0,573000.0,631666.667,600500.0,667500.0,505000.0],"type":"choropleth"},{"locationmode":"USA-states","locations":["WA","NE","CA","MN","MO","WI","PA","OR","IL","CO","MA","IN","KS","OH","FL","AK","IA","VA","NV","TX","AZ","UT","MT","MI","OK","HI","AR"],"mode":"text","text":["WA","NE","CA","MN","MO","WI","PA","OR","IL","CO","MA","IN","KS","OH","FL","AK","IA","VA","NV","TX","AZ","UT","MT","MI","OK","HI","AR"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111, ...

# %%
# the median price of a house per state

state_list = df_h['state'].value_counts().index

state_median = {}
for name in state_list:
    state_median[name] = round(df_h[(df_h['state'] == name)]['price'].median(),3)
    
    
state_median_price = pd.DataFrame.from_dict(state_median, orient='index',columns=['median_price'])
state_median_price.reset_index(inplace=True)
state_median_price.rename(columns={"index":'state'}, inplace=True)
state_median_price['code'] = state_avg_price['state'].map(code)


state_median_price
# Out:
#             state  median_price code
# 0      Washington      680000.0   WA
# 1        Nebraska      700000.0   NE
# 2      California      675000.0   CA
# 3       Minnesota      675000.0   MN
# 4        Missouri      740000.0   MO
# 5       Wisconsin      660000.0   WI
# 6    Pennsylvania      730000.0   PA
# 7          Oregon      684500.0   OR
# 8        Illinois      640000.0   IL
# 9        Colorado      748000.0   CO
# 10  Massachusetts      715000.0   MA
# 11        Indiana      685000.0   IN
# 12         Kansas      653750.0   KS
# 13           Ohio      705000.0   OH
# 14        Florida      772500.0   FL
# 15         Alaska      705000.0   AK
# 16           Iowa      652500.0   IA
# 17       Virginia      850000.0   VA
# 18         Nevada      775000.0   NV
# 19          Texas      602976.5   TX
# 20        Arizona      475687.5   AZ
# 21           Utah      530000.0   UT
# 22        Montana      599000.0   MT
# 23       Michigan      680000.0   MI
# 24       Oklahoma      600500.0   OK
# 25         Hawaii      667500.0   HI
# 26       Arkansas      505000.0   AR

# %%
fig = px.choropleth(state_median_price,
                    locations='code',
                    color='median_price',
                    color_continuous_scale='spectral_r',
                    hover_name='state',
                    locationmode='USA-states',
                    labels={'median_price':'Price'},
                    scope='usa')

fig.add_scattergeo(locations=state_avg_price['code'],
                   locationmode='USA-states',
                  text=state_avg_price['code'],
                  mode='text')

fig.update_layout(
    title={'text':'Median Price of House per State',
           'xanchor':'center',
           'yanchor':'top',
           'x':0.5,})
# Out:
# <div>                            <div id="78daeabd-36d5-408e-b44b-ffb6d36d186a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78daeabd-36d5-408e-b44b-ffb6d36d186a")) {                    Plotly.newPlot(                        "78daeabd-36d5-408e-b44b-ffb6d36d186a",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>code=%{location}<br>Price=%{z}<extra></extra>","hovertext":["Washington","Nebraska","California","Minnesota","Missouri","Wisconsin","Pennsylvania","Oregon","Illinois","Colorado","Massachusetts","Indiana","Kansas","Ohio","Florida","Alaska","Iowa","Virginia","Nevada","Texas","Arizona","Utah","Montana","Michigan","Oklahoma","Hawaii","Arkansas"],"locationmode":"USA-states","locations":["WA","NE","CA","MN","MO","WI","PA","OR","IL","CO","MA","IN","KS","OH","FL","AK","IA","VA","NV","TX","AZ","UT","MT","MI","OK","HI","AR"],"name":"","z":[680000.0,700000.0,675000.0,675000.0,740000.0,660000.0,730000.0,684500.0,640000.0,748000.0,715000.0,685000.0,653750.0,705000.0,772500.0,705000.0,652500.0,850000.0,775000.0,602976.5,475687.5,530000.0,599000.0,680000.0,600500.0,667500.0,505000.0],"type":"choropleth"},{"locationmode":"USA-states","locations":["WA","NE","CA","MN","MO","WI","PA","OR","IL","CO","MA","IN","KS","OH","FL","AK","IA","VA","NV","TX","AZ","UT","MT","MI","OK","HI","AR"],"mode":"text","text":["WA","NE","CA","MN","MO","WI","PA","OR","IL","CO","MA","IN","KS","OH","FL","AK","IA","VA","NV","TX","AZ","UT","MT","MI","OK","HI","AR"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"# ...
